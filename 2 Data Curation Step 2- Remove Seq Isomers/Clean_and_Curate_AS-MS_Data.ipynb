# %%
# Prior to this, peptides have already been filtered by library design in Step 0
# This notebook will take AS-MS data that has been filtered by library design and rigorously remove the sequence isomers

# %%
import os, difflib
import pandas as pd
import numpy as np

# %%
# file_list = [],
# for file in os.listdir(os.getcwd()):
#     if file.endswith('.csv'):
#         file_list.append(file)

# %%
file = 'Example Raw Data.csv'
df = pd.read_csv(file)

# %%
df
# Out:
#      Notebook   Scan        Peptide  ALC (%)       m/z  z  Obs Parent Mass  \
# 0     284-126   3203  NNGGGLGSGQASK       89  573.2864  2        1144.5582
# 1     268-020   5770  TGSAADVADYSAK       96  627.7993  2        1253.5840
# 2     268-186    318  GSASGLSFKGSHK       99  421.2267  3        1260.6582
# 3     256-092  10187  GMASDMADYAAGK       99  643.7775  2        1285.5404
# 4     268-175   4195  GLASGLSFKGSHK       99  429.9094  3        1286.7063
# ...       ...    ...            ...      ...       ... ..              ...
# 4262  284-079  12732  WYTHMMFPWMWFK       95  630.6179  3        1888.8318
# 4263  261-179  26317  LYYYMTPWWPYWK       95  948.4512  2        1894.8878
# 4264  228-002  38310  YLYYMTPWPWYWK       98  956.4479  2        1910.8812
# 4265  271-146   5783  WRNKFWLQWHWYK       97  495.0081  4        1976.0032
# 4266  261-158  11356  WVYWRYYWRYPKK       96  499.0156  4        1992.0332
#
#          RT       Mass  ppm
# 0     22.55  1144.5586 -0.3
# 1     27.06  1253.5889 -3.8
# 2      9.91  1260.6575  0.7
# 3     43.45  1285.5432 -2.2
# 4     25.99  1286.7095 -2.5
# ...     ...        ...  ...
# 4262  74.98  1888.8403 -4.4
# 4263  87.87  1894.8906 -1.5
# 4264  96.49  1910.8855 -2.2
# 4265  48.36  1976.0110 -3.9
# 4266  41.88  1992.0310  1.1
#
# [4267 rows x 10 columns]

# %%
# Filter out based on ALC, ppm, and Uniqueness create a new dataframe
ALC_Cutoff = 85 # inclusive of this number and higher
ppm_error_cutoff = 10 # exclusive of this number, i.e., if 10, then 9.9 ppm is kept

# ALC, which is sequencing confidence, This was previously filtered, and is filtered again here
ALC_list = df['ALC (%)'].to_list()
Good_ALC_list = []
for i,ALC in enumerate(ALC_list):
    if ALC > ALC_Cutoff-1: Good_ALC_list.append(i)
df_ALC = df.iloc[Good_ALC_list,:]

# ppm error
ppm_list = df_ALC['ppm'].to_list()
Good_ppm_list = []
for i,ppm in enumerate(ppm_list):
    if ppm > -ppm_error_cutoff and ppm < ppm_error_cutoff: Good_ppm_list.append(i)
df = df_ALC.iloc[Good_ppm_list,:]

# # Use this if it is needed
# # Remove nonunique peptides
# Unique_list = df_ppm['Uniqueness'].to_list()
# Good_unique_list = []
# for i,uniq in enumerate(Unique_list):
#     if uniq == 'UNIQUE': Good_unique_list.append(i)
# df = df_ppm.iloc[Good_unique_list,:] # overwrites earlier dataframe

# Calculate and sort by observed parent mass, OPM
m_z = df['m/z'].to_list()
zs = df['z'].to_list()
OPM = []
for i,mz in enumerate(m_z):
    OPM.append(mz*zs[i]-zs[i]*1.0073)
df['Obs Parent Mass'] = OPM
df = df.sort_values(by=['Obs Parent Mass']) # technically unnecessary, but useful to allow manual inspection

df.reset_index(drop=True,inplace=True) # required such that the indices of lists and dataframes match

# Clean up peptides for comparison, remove KU if it exists, remove ' 's that sometime exist
peptides_start = df['Peptide'].tolist()
peptides = [pep.replace('KU', 'K') for pep in peptides_start]
betterpeptides = [string for string in peptides if string != '']
df['Peptide'] = betterpeptides
print(f'ALC, ppm, and Unique filtering completed, removed {len(ALC_list)-len(peptides_start)} peptides')
# Out:
# ALC, ppm, and Unique filtering completed, removed 66 peptides

# %%
df
# Out:
#      Notebook   Scan        Peptide  ALC (%)       m/z  z  Obs Parent Mass  \
# 0     284-126   3203  NNGGGLGSGQASK       89  573.2864  2        1144.5582
# 1     268-020   5770  TGSAADVADYSAK       96  627.7993  2        1253.5840
# 2     268-186    318  GSASGLSFKGSHK       99  421.2267  3        1260.6582
# 3     256-092  10187  GMASDMADYAAGK       99  643.7775  2        1285.5404
# 4     268-175   4195  GLASGLSFKGSHK       99  429.9094  3        1286.7063
# ...       ...    ...            ...      ...       ... ..              ...
# 4196  284-079  12732  WYTHMMFPWMWFK       95  630.6179  3        1888.8318
# 4197  261-179  26317  LYYYMTPWWPYWK       95  948.4512  2        1894.8878
# 4198  228-002  38310  YLYYMTPWPWYWK       98  956.4479  2        1910.8812
# 4199  271-146   5783  WRNKFWLQWHWYK       97  495.0081  4        1976.0032
# 4200  261-158  11356  WVYWRYYWRYPKK       96  499.0156  4        1992.0332
#
#          RT       Mass  ppm
# 0     22.55  1144.5586 -0.3
# 1     27.06  1253.5889 -3.8
# 2      9.91  1260.6575  0.7
# 3     43.45  1285.5432 -2.2
# 4     25.99  1286.7095 -2.5
# ...     ...        ...  ...
# 4196  74.98  1888.8403 -4.4
# 4197  87.87  1894.8906 -1.5
# 4198  96.49  1910.8855 -2.2
# 4199  48.36  1976.0110 -3.9
# 4200  41.88  1992.0310  1.1
#
# [4201 rows x 10 columns]

# %%
# Step 1, remove peptide duplicates
df = df.drop_duplicates(subset=['Peptide'])
df.reset_index(drop=True,inplace=True)
print(f'Step 1 completed, removed {len(peptides_start)-len(df.index)} duplicates')
# Out:
# Step 1 completed, removed 0 duplicates

# %%
df
# Out:
#      Notebook   Scan        Peptide  ALC (%)       m/z  z  Obs Parent Mass  \
# 0     284-126   3203  NNGGGLGSGQASK       89  573.2864  2        1144.5582
# 1     268-020   5770  TGSAADVADYSAK       96  627.7993  2        1253.5840
# 2     268-186    318  GSASGLSFKGSHK       99  421.2267  3        1260.6582
# 3     256-092  10187  GMASDMADYAAGK       99  643.7775  2        1285.5404
# 4     268-175   4195  GLASGLSFKGSHK       99  429.9094  3        1286.7063
# ...       ...    ...            ...      ...       ... ..              ...
# 4196  284-079  12732  WYTHMMFPWMWFK       95  630.6179  3        1888.8318
# 4197  261-179  26317  LYYYMTPWWPYWK       95  948.4512  2        1894.8878
# 4198  228-002  38310  YLYYMTPWPWYWK       98  956.4479  2        1910.8812
# 4199  271-146   5783  WRNKFWLQWHWYK       97  495.0081  4        1976.0032
# 4200  261-158  11356  WVYWRYYWRYPKK       96  499.0156  4        1992.0332
#
#          RT       Mass  ppm
# 0     22.55  1144.5586 -0.3
# 1     27.06  1253.5889 -3.8
# 2      9.91  1260.6575  0.7
# 3     43.45  1285.5432 -2.2
# 4     25.99  1286.7095 -2.5
# ...     ...        ...  ...
# 4196  74.98  1888.8403 -4.4
# 4197  87.87  1894.8906 -1.5
# 4198  96.49  1910.8855 -2.2
# 4199  48.36  1976.0110 -3.9
# 4200  41.88  1992.0310  1.1
#
# [4201 rows x 10 columns]

# %%
# Step 2: Remove sequence isomers with the same precursor mass -OR- with a different specific precursor mass
# There are multiple situations where the removal of precursors of different masses is justified including:
    # 1) incorrect monoisotopic precursor selection (abs delta of 1)
    # 2) oxidations (abs delta of 16, 32)
    # 3) and sodium adduct (abs delta of 22)
# 0.69 similarity was emperically determined and is very lenient in the comparison (multiple mismatches / shifts allowed)
# the mass differences are the tight requirement here; and thus, and thus, ALC cutoffs are not considered
# RT differences are not considered in case the data was acquired using different gradients, though they were used to set the similarity requirement
# The highest ALC peptide will be retained, with ppm as tie-breaker

# Extract lists from dataframe for enumeration
peptides = df['Peptide'].tolist()
OPM = df['Obs Parent Mass'].tolist()
ALC = df['ALC (%)'].tolist()
ppm = df['ppm'].tolist()

# Make a list of all the peptides to remove, Step 2:
similarity_cutoff = 0.69      # more than this
Mass_diff_list = [0,1,16,32,22] # and a mass difference within this list

to_drop = []
for i in range(len(peptides)):
    if len(peptides) > 500 and i % 100 == 0: print(f"Step 2: {i} of {len(peptides)}")
    for k in range(len(peptides)):
        sim = difflib.SequenceMatcher(a=peptides[k], b=peptides[i])
        simz = sim.ratio()
        difference = np.abs(float(OPM[i]) - float(OPM[k]))
        if i != k and simz > similarity_cutoff:
            # print(f"Trouble {peptides[k]} {ALC[k]} {round(float(OPM[k]),3)} and {peptides[i]} {ALC[i]} {round(float(OPM[i]),3)}, similarity {round(float(simz),3)} difference {round(float(difference),3)}")
            if round(float(difference)) in Mass_diff_list:
                if ALC[k] > ALC[i]:
                    print(f"1: I've marked {peptides[i]} {ALC[i]}, index is {i}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}")
                    to_drop.append(i)
                elif ALC[k] < ALC[i]:
                    print(f"2: I've marked {peptides[k]} {ALC[k]}, index is {k}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}")
                    to_drop.append(k)
                elif ALC[k] == ALC[i]:    
                    if abs(float(ppm[k])) < abs(float(ppm[i])):
                        print(f"3: I've marked {peptides[k]} {ALC[k]}, index is {k}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}")
                        to_drop.append(k)
                    elif abs(float(ppm[i])) < abs(float(ppm[k])):
                        print(f"4: I've marked {peptides[i]} {ALC[i]}, index is {i}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}")
                        to_drop.append(i)
                    else:
                        print(f"5: I've marked {peptides[k]} {ALC[k]}, index is {k}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}")
                        to_drop.append(k)
# Out:
# Step 2: 0 of 4201
# 2: I've marked DLADYAAVDGGFK 91, index is 19, similarity 0.692, Mass difference 32.004
# 1: I've marked LTTGDAPDYADGK 88, index is 10, similarity 0.692, Mass difference 21.954
# 1: I've marked PDVPDYAVASGDK 90, index is 14, similarity 0.692, Mass difference 32.064
# 3: I've marked APGDLPDYAVTNK 95, index is 27, similarity 0.692, Mass difference 22.094
# 2: I've marked NSFEGDAPDYAGK 90, index is 43, similarity 0.692, Mass difference 32.007
# 1: I've marked DLADYAAVDGGFK 91, index is 19, similarity 0.692, Mass difference 32.004
# 1: I've marked DLADYAAVDGGFK 91, index is 19, similarity 0.692, Mass difference 15.996
# 2: I've marked LTTGDAPDYADGK 88, index is 10, similarity 0.692, Mass difference 21.954
# 4: I've marked SVDTGDMADYAGK 95, index is 20, similarity 0.692, Mass difference 15.977
# 1: I've marked PGQNLDVGDYAAK 96, index is 21, similarity 0.692, Mass difference 21.981
# 1: I've marked QGSADLPDYAANK 97, index is 22, similarity 0.692, Mass difference 31.992
# 4: I've marked GGVLRDVSDYAAK 89, index is 23, similarity 0.769, Mass difference 21.995
# 2: I've marked DLADYAAVDGGFK 91, index is 19, similarity 0.692, Mass difference 15.996
# 2: I've marked HAGMTDLPDYAAK 96, index is 80, similarity 0.692, Mass difference 32.018
# 2: I've marked VSYDDVADYAGSK 94, index is 79, similarity 0.692, Mass difference 31.959
# 4: I've marked APGDLPDYAVTNK 95, index is 27, similarity 0.692, Mass difference 22.094
# 3: I've marked SVDTGDMADYAGK 95, index is 20, similarity 0.692, Mass difference 15.977
# 2: I've marked PDVPDYAVASGDK 90, index is 14, similarity 0.692, Mass difference 32.064
# 2: I've marked MSTNPDVGDYAAK 94, index is 68, similarity 0.923, Mass difference 15.991
# 1: I've marked MSTNPDVDGYAAK 97, index is 39, similarity 0.769, Mass difference 32.071
# 2: I've marked PGQNLDVGDYAAK 96, index is 21, similarity 0.692, Mass difference 21.981
# 2: I've marked ETGDLADYASSEK 97, index is 71, similarity 0.769, Mass difference 15.922
# 1: I've marked NSFEGDAPDYAGK 90, index is 43, similarity 0.692, Mass difference 32.007
# 3: I've marked GGVLRDVSDYAAK 89, index is 23, similarity 0.769, Mass difference 21.995
# 2: I've marked HAGMTDLPDYAAK 96, index is 80, similarity 0.692, Mass difference 16.01
# 1: I've marked LTNSGLAYKGSHK 85, index is 50, similarity 0.769, Mass difference 0.001
# 1: I've marked LTNSGLAYKGSHK 85, index is 50, similarity 0.692, Mass difference 15.962
# 2: I've marked LTNSGLAYKGSHK 85, index is 50, similarity 0.769, Mass difference 0.001
# 1: I've marked KEASGLAYKGSHK 90, index is 51, similarity 0.692, Mass difference 15.962
# 2: I've marked GYPDVEDYSAGTK 98, index is 106, similarity 0.692, Mass difference 21.91
# 2: I've marked QGSADLPDYAANK 97, index is 22, similarity 0.692, Mass difference 31.992
# 3: I've marked FLVLDGPDYAAPK 99, index is 116, similarity 0.692, Mass difference 22.131
# 1: I've marked MSTNPDVGDYAAK 94, index is 68, similarity 0.923, Mass difference 15.991
# 1: I've marked MSTNPDVGDYAAK 94, index is 68, similarity 0.769, Mass difference 16.081
# 1: I've marked ETGDLADYASSEK 97, index is 71, similarity 0.769, Mass difference 15.922
# 1: I've marked ETGDLADYASSEK 97, index is 71, similarity 0.692, Mass difference 16.061
# 1: I've marked NPGGFDMTDYAAK 97, index is 73, similarity 0.846, Mass difference 15.997
# 2: I've marked VDLADYADHGEAK 94, index is 111, similarity 0.692, Mass difference 16.008
# 1: I've marked VSYDDVADYAGSK 94, index is 79, similarity 0.692, Mass difference 31.959
# 1: I've marked HAGMTDLPDYAAK 96, index is 80, similarity 0.692, Mass difference 32.018
# 1: I've marked HAGMTDLPDYAAK 96, index is 80, similarity 0.692, Mass difference 16.01
# 3: I've marked PDSALEDLADYAK 99, index is 120, similarity 0.769, Mass difference 16.024
# 4: I've marked PDANLDQADYAAK 99, index is 82, similarity 0.692, Mass difference 16.066
# 1: I've marked PVSGMLDVPDYAK 92, index is 83, similarity 0.692, Mass difference 15.956
# 1: I've marked PVSGMLDVPDYAK 92, index is 83, similarity 0.692, Mass difference 21.947
# 2: I've marked LTNSGLAYKGSHK 85, index is 50, similarity 0.692, Mass difference 15.962
# 2: I've marked KEASGLAYKGSHK 90, index is 51, similarity 0.692, Mass difference 15.962
# 1: I've marked AVDQVDAQDYAAK 88, index is 86, similarity 0.692, Mass difference 31.93
# 1: I've marked AVDQVDAQDYAAK 88, index is 86, similarity 0.692, Mass difference 1.036
# 4: I've marked DSLADYAGDPWGK 98, index is 89, similarity 0.692, Mass difference 1.002
# 1: I've marked SQADLPDYSATVK 96, index is 90, similarity 0.692, Mass difference 21.931
# 2: I've marked AVDQVDAQDYAAK 88, index is 86, similarity 0.692, Mass difference 1.036
# 3: I've marked PYLANDVADYAAK 99, index is 133, similarity 0.692, Mass difference 15.992
# 3: I've marked DSLADYAGDPWGK 98, index is 89, similarity 0.692, Mass difference 1.002
# 3: I've marked VMVSSDVPDYASK 99, index is 99, similarity 0.692, Mass difference 0.989
# 2: I've marked ANVSDVPDYAFSK 95, index is 135, similarity 0.692, Mass difference 15.994
# 4: I've marked VWSVDVADYASGK 99, index is 96, similarity 0.692, Mass difference 31.988
# 4: I've marked VMVSSDVPDYASK 99, index is 99, similarity 0.692, Mass difference 0.989
# 2: I've marked VMVSSDVPDAYSK 90, index is 142, similarity 0.923, Mass difference 15.995
# Step 2: 100 of 4201
# 2: I've marked MSTNPDVDGYAAK 97, index is 39, similarity 0.769, Mass difference 32.071
# 2: I've marked MSTNPDVGDYAAK 94, index is 68, similarity 0.769, Mass difference 16.081
# 2: I've marked EQGHADLVDYASK 86, index is 224, similarity 0.692, Mass difference 31.987
# 1: I've marked TAADLPDYAAHKK 93, index is 104, similarity 0.692, Mass difference 21.985
# 4: I've marked TSMEDVADYADGK 99, index is 105, similarity 0.923, Mass difference 15.994
# 1: I've marked GYPDVEDYSAGTK 98, index is 106, similarity 0.692, Mass difference 21.91
# 2: I've marked ETGDLADYASSEK 97, index is 71, similarity 0.692, Mass difference 16.061
# 2: I've marked NPGGFDMTDYAAK 97, index is 73, similarity 0.846, Mass difference 15.997
# 1: I've marked GVSTTDAQDYAFK 98, index is 109, similarity 0.692, Mass difference 21.994
# 1: I've marked VDLADYADHGEAK 94, index is 111, similarity 0.692, Mass difference 16.008
# 2: I've marked GLANDLHDYAGYK 97, index is 242, similarity 0.692, Mass difference 32.005
# 4: I've marked FLVLDGPDYAAPK 99, index is 116, similarity 0.692, Mass difference 22.131
# 3: I've marked VALADDPRDYAAK 99, index is 113, similarity 0.692, Mass difference 1.022
# 3: I've marked VMQVDEPDYAAGK 99, index is 176, similarity 0.692, Mass difference 15.978
# 2: I've marked PVSGMLDVPDYAK 92, index is 83, similarity 0.692, Mass difference 15.956
# 4: I've marked PDSALEDLADYAK 99, index is 120, similarity 0.769, Mass difference 16.024
# 3: I've marked PDANLDQADYAAK 99, index is 82, similarity 0.692, Mass difference 16.066
# 2: I've marked GSNSDLQDYAEPK 96, index is 183, similarity 0.692, Mass difference 15.924
# 2: I've marked HLLDLPDYASSAK 96, index is 213, similarity 0.692, Mass difference 22.017
# 2: I've marked TVAQNDVGDYAEK 97, index is 130, similarity 0.692, Mass difference 1.017
# 2: I've marked YPWALDAADYAGK 95, index is 268, similarity 0.769, Mass difference 32.022
# 4: I've marked SSDVDAPDYAELK 99, index is 129, similarity 0.692, Mass difference 32.003
# 1: I've marked TVAQNDVGDYAEK 97, index is 130, similarity 0.769, Mass difference 1.017
# 4: I've marked PYLANDVADYAAK 99, index is 133, similarity 0.692, Mass difference 15.992
# 4: I've marked PYLANDVADYAAK 99, index is 133, similarity 0.692, Mass difference 31.952
# 1: I've marked SAAMLDAQDYAEK 94, index is 134, similarity 0.923, Mass difference 15.987
# 1: I've marked ANVSDVPDYAFSK 95, index is 135, similarity 0.692, Mass difference 15.994
# 2: I've marked VMVSSDVPDAYSK 90, index is 142, similarity 0.692, Mass difference 0.989
# 2: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.692, Mass difference 32.055
# 3: I've marked ELSGSTDVEDYAK 98, index is 139, similarity 0.692, Mass difference 0.971
# 1: I've marked SLKGDVEDYAGMK 98, index is 136, similarity 0.692, Mass difference 31.954
# 2: I've marked PVSGMLDVPDYAK 92, index is 83, similarity 0.692, Mass difference 21.947
# 4: I've marked ELSGSTDVEDYAK 98, index is 139, similarity 0.692, Mass difference 0.971
# 4: I've marked DPGTYDLVDYAGK 99, index is 140, similarity 0.692, Mass difference 1.009
# 1: I've marked VMVSSDVPDAYSK 90, index is 142, similarity 0.923, Mass difference 15.995
# 1: I've marked VMVSSDVPDAYSK 90, index is 142, similarity 0.692, Mass difference 0.989
# 2: I've marked HKYGADVVDYAAK 92, index is 245, similarity 0.692, Mass difference 22.105
# 3: I've marked DPGTYDLVDYAGK 99, index is 140, similarity 0.692, Mass difference 1.009
# 3: I've marked VGDPGDLHDYAEK 99, index is 150, similarity 0.692, Mass difference 0.981
# 2: I've marked VNGTDDLTDYSAK 96, index is 100, similarity 0.692, Mass difference 16.087
# 4: I've marked VGDPGDLHDYAEK 99, index is 150, similarity 0.692, Mass difference 0.981
# 4: I've marked VGDPGDLHDYAEK 99, index is 150, similarity 0.692, Mass difference 16.013
# 2: I've marked VGEHDDLEDYAGK 98, index is 317, similarity 0.692, Mass difference 31.99
# 2: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.769, Mass difference 32.111
# 2: I've marked SQADLPDYSATVK 96, index is 90, similarity 0.692, Mass difference 21.931
# 1: I've marked ASLSYDVQDYAGK 97, index is 154, similarity 0.692, Mass difference 22.013
# 3: I've marked TSMEDVADYADGK 99, index is 105, similarity 0.923, Mass difference 15.994
# 1: I've marked QSPVDLADYSAQK 92, index is 170, similarity 0.692, Mass difference 0.997
# 1: I've marked QSPVDLADYSAQK 92, index is 170, similarity 0.769, Mass difference 0.997
# 1: I've marked NGDASMDVDYAHK 87, index is 173, similarity 0.923, Mass difference 15.995
# 1: I've marked NGDASMDVDYAHK 87, index is 173, similarity 0.692, Mass difference 22.03
# 1: I've marked NGDASMDVDYAHK 87, index is 173, similarity 0.692, Mass difference 22.129
# 4: I've marked VMQVDEPDYAAGK 99, index is 176, similarity 0.692, Mass difference 15.978
# 2: I've marked VMQVDEDPYAAGK 96, index is 253, similarity 0.923, Mass difference 15.992
# 2: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.692, Mass difference 22.064
# 2: I've marked QSPVDLADYSAQK 92, index is 170, similarity 0.692, Mass difference 0.997
# 2: I've marked FGPVDLMQTSQGK 85, index is 185, similarity 0.769, Mass difference 1.002
# 2: I've marked QSPVDLADYSAQK 92, index is 170, similarity 0.769, Mass difference 0.997
# 2: I've marked EWSPDLGADYASK 92, index is 252, similarity 0.692, Mass difference 15.957
# 2: I've marked TAADLPDYAAHKK 93, index is 104, similarity 0.692, Mass difference 21.985
# 1: I've marked AADVKDYAAYAHK 94, index is 179, similarity 0.692, Mass difference 16.0
# 2: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.769, Mass difference 22.01
# 2: I've marked EMPPSDAEDYAAK 88, index is 258, similarity 0.923, Mass difference 15.992
# 1: I've marked GSNSDLQDYAEPK 96, index is 183, similarity 0.692, Mass difference 15.924
# 2: I've marked QGMSPDLQDYASK 90, index is 260, similarity 0.692, Mass difference 16.016
# 1: I've marked FGPVDLMQTSQGK 85, index is 185, similarity 0.769, Mass difference 1.002
# 4: I've marked LAWKGDVADYSAK 99, index is 186, similarity 0.692, Mass difference 16.011
# 1: I've marked MLDAPDYAQDSAK 87, index is 187, similarity 0.846, Mass difference 15.994
# 1: I've marked MLDAPDYAQDSAK 87, index is 187, similarity 0.692, Mass difference 31.984
# 2: I've marked GVSTTDAQDYAFK 98, index is 109, similarity 0.692, Mass difference 21.994
# 2: I've marked DSWVDDTADYAAK 97, index is 373, similarity 0.692, Mass difference 31.973
# 2: I've marked GLMVDFFAYQAGK 95, index is 314, similarity 0.692, Mass difference 22.038
# 4: I've marked VTPGFDLEDYAAK 98, index is 194, similarity 0.692, Mass difference 21.944
# 2: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.692, Mass difference 22.065
# 1: I've marked VTPGFDLEDYAAK 98, index is 194, similarity 0.769, Mass difference 32.039
# 1: I've marked STGLSDVRDYADK 98, index is 195, similarity 0.692, Mass difference 0.979
# 2: I've marked STGLSDVRDYADK 98, index is 195, similarity 0.692, Mass difference 0.979
# 2: I've marked TTGFSDLPDYANK 98, index is 207, similarity 0.692, Mass difference 0.991
# Step 2: 200 of 4201
# 2: I've marked LAHLPDKSDYAAK 85, index is 209, similarity 0.692, Mass difference 1.029
# 2: I've marked SAAMLDAQDYAEK 94, index is 134, similarity 0.923, Mass difference 15.987
# 1: I've marked NSTSMSDLPDYAK 92, index is 203, similarity 0.692, Mass difference 0.03
# 3: I've marked VWSVDVADYASGK 99, index is 96, similarity 0.692, Mass difference 31.988
# 3: I've marked FGYPDAPDYASVK 99, index is 211, similarity 0.692, Mass difference 1.0
# 1: I've marked TTGFSDLPDYANK 98, index is 207, similarity 0.692, Mass difference 0.991
# 2: I've marked NSTSMSDLPDYAK 92, index is 203, similarity 0.692, Mass difference 0.03
# 1: I've marked WVPADADPYAVPK 85, index is 208, similarity 0.692, Mass difference 31.994
# 1: I've marked LAHLPDKSDYAAK 85, index is 209, similarity 0.692, Mass difference 1.029
# 1: I've marked LAHLPDKSDYAAK 85, index is 209, similarity 0.692, Mass difference 15.934
# 1: I've marked LAHLPDKSDYAAK 85, index is 209, similarity 0.692, Mass difference 31.972
# 4: I've marked FGYPDAPDYASVK 99, index is 211, similarity 0.692, Mass difference 1.0
# 1: I've marked HLLDLPDYASSAK 96, index is 213, similarity 0.692, Mass difference 22.017
# 4: I've marked PLVDPDLADYANK 99, index is 215, similarity 0.692, Mass difference 32.039
# 2: I've marked WSVWDVGDYAAGK 94, index is 352, similarity 0.692, Mass difference 22.042
# 2: I've marked FLGYDAGPDYAHK 96, index is 355, similarity 0.692, Mass difference 22.037
# 3: I've marked FVGDHPDYAEVSK 99, index is 432, similarity 0.692, Mass difference 32.04
# 3: I've marked VGDPGDLHDYAEK 99, index is 150, similarity 0.692, Mass difference 16.013
# 2: I've marked VGEHDDLEDYAGK 98, index is 317, similarity 0.692, Mass difference 15.978
# 2: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.692, Mass difference 16.099
# 1: I've marked EQGHADLVDYASK 86, index is 224, similarity 0.692, Mass difference 31.987
# 3: I've marked ETVLDVMDYAATK 99, index is 371, similarity 0.692, Mass difference 22.03
# 1: I've marked DNDVPDYADLGLK 97, index is 232, similarity 0.692, Mass difference 21.985
# 2: I've marked HGGKSDKVDMAFK 92, index is 237, similarity 0.769, Mass difference 0.999
# 4: I've marked EPVQNDVADYSAK 99, index is 235, similarity 0.692, Mass difference 22.056
# 1: I've marked HGGKSDKVDMAFK 92, index is 237, similarity 0.769, Mass difference 0.999
# 1: I've marked GLANDLHDYAGYK 97, index is 242, similarity 0.692, Mass difference 32.005
# 1: I've marked HKYGADVVDYAAK 92, index is 245, similarity 0.692, Mass difference 22.105
# 1: I've marked HKYGADVVDYAAK 92, index is 245, similarity 0.769, Mass difference 21.977
# 1: I've marked HKYGADVVDYAAK 92, index is 245, similarity 0.769, Mass difference 32.063
# 2: I've marked EWSPDLGADYASK 92, index is 252, similarity 0.692, Mass difference 1.083
# 3: I've marked LAADMVDYADRAK 99, index is 255, similarity 0.692, Mass difference 1.089
# 4: I've marked PVADTDLEDYATK 99, index is 248, similarity 0.692, Mass difference 16.004
# 3: I've marked LAADMVDYADRAK 99, index is 255, similarity 0.692, Mass difference 0.971
# 2: I've marked NGDASMDVDYAHK 87, index is 173, similarity 0.923, Mass difference 15.995
# 1: I've marked EWSPDLGADYASK 92, index is 252, similarity 0.692, Mass difference 15.957
# 1: I've marked EWSPDLGADYASK 92, index is 252, similarity 0.692, Mass difference 1.083
# 2: I've marked QGMSPDLQDYASK 90, index is 260, similarity 0.692, Mass difference 1.002
# 1: I've marked VMQVDEDPYAAGK 96, index is 253, similarity 0.923, Mass difference 15.992
# 2: I've marked HVDLEDYAENAGK 88, index is 406, similarity 0.692, Mass difference 22.014
# 1: I've marked VMQVDEDPYAAGK 96, index is 253, similarity 0.692, Mass difference 22.052
# 2: I've marked ASLSYDVQDYAGK 97, index is 154, similarity 0.692, Mass difference 22.013
# 2: I've marked AADVKDYAAYAHK 94, index is 179, similarity 0.692, Mass difference 16.0
# 4: I've marked LAADMVDYADRAK 99, index is 255, similarity 0.692, Mass difference 1.089
# 1: I've marked EMPPSDAEDYAAK 88, index is 258, similarity 0.923, Mass difference 15.992
# 2: I've marked MGLPTDHHDYAAK 93, index is 494, similarity 0.692, Mass difference 32.02
# 2: I've marked FGLPTDHHDYAAK 90, index is 504, similarity 0.692, Mass difference 32.05
# 1: I've marked QGMSPDLQDYASK 90, index is 260, similarity 0.692, Mass difference 16.016
# 1: I've marked QGMSPDLQDYASK 90, index is 260, similarity 0.692, Mass difference 1.002
# 1: I've marked AVTEEDLEDYAGK 98, index is 261, similarity 0.692, Mass difference 31.993
# 2: I've marked GPVQGDVMPYAYK 88, index is 269, similarity 0.846, Mass difference 1.001
# 1: I've marked LGKDLEDYSSANK 92, index is 264, similarity 0.692, Mass difference 15.933
# 2: I've marked MLDAPDYAQDSAK 87, index is 187, similarity 0.846, Mass difference 15.994
# 1: I've marked MLDAPDYANTDAK 93, index is 266, similarity 0.692, Mass difference 15.99
# 1: I've marked YPWALDAADYAGK 95, index is 268, similarity 0.769, Mass difference 32.022
# 1: I've marked YPWALDAADYAGK 95, index is 268, similarity 0.692, Mass difference 22.081
# 1: I've marked GPVQGDVMPYAYK 88, index is 269, similarity 0.846, Mass difference 1.001
# 4: I've marked WGSLTDLTDYAAK 99, index is 270, similarity 0.692, Mass difference 22.056
# 3: I've marked SSDVDAPDYAELK 99, index is 129, similarity 0.692, Mass difference 32.003
# 4: I've marked EFDLADYAATTPK 99, index is 275, similarity 0.692, Mass difference 0.994
# 2: I've marked EGVFDLADYAMDK 85, index is 521, similarity 0.692, Mass difference 31.969
# 4: I've marked VSAGDMEDYAEQK 93, index is 276, similarity 0.846, Mass difference 15.991
# 3: I've marked PYLANDVADYAAK 99, index is 133, similarity 0.692, Mass difference 31.952
# 3: I've marked EFDLADYAATTPK 99, index is 275, similarity 0.692, Mass difference 0.994
# 4: I've marked TFDLQDYSAAPSK 99, index is 280, similarity 0.692, Mass difference 15.993
# 1: I've marked YAESDTPDYAALK 89, index is 287, similarity 0.846, Mass difference 0.004
# 2: I've marked YAESDTPDYAALK 89, index is 287, similarity 0.846, Mass difference 0.004
# 2: I've marked QTHAVDLPDYSAK 98, index is 296, similarity 0.692, Mass difference 0.994
# 4: I've marked TVTDLPDYAHSPK 99, index is 290, similarity 0.692, Mass difference 15.923
# 2: I've marked SLKGDVEDYAGMK 98, index is 136, similarity 0.692, Mass difference 31.954
# 2: I've marked NGDASMDVDYAHK 87, index is 173, similarity 0.692, Mass difference 22.03
# 2: I've marked GLWNDVQDYAAPK 96, index is 550, similarity 0.692, Mass difference 32.087
# 2: I've marked LAHLPDKSDYAAK 85, index is 209, similarity 0.692, Mass difference 15.934
# 2: I've marked FDVMPYASLTTGK 97, index is 308, similarity 0.846, Mass difference 1.011
# 1: I've marked QTHAVDLPDYSAK 98, index is 296, similarity 0.692, Mass difference 0.994
# 1: I've marked HVAWDLGADYAVK 91, index is 297, similarity 0.692, Mass difference 15.989
# 2: I've marked HALDDWGADYADK 87, index is 547, similarity 0.692, Mass difference 31.917
# 1: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.692, Mass difference 32.055
# 2: I've marked NGDASMDVDYAHK 87, index is 173, similarity 0.692, Mass difference 22.129
# 1: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.692, Mass difference 22.064
# 1: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.769, Mass difference 22.01
# 1: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.846, Mass difference 0.985
# 1: I've marked TGLTAKDVDYAYK 85, index is 299, similarity 0.769, Mass difference 15.957
# 1: I've marked TGLTAKDVDYAYK 85, index is 299, similarity 0.692, Mass difference 31.977
# Step 2: 300 of 4201
# 2: I've marked EYGMVDAEDYTGK 94, index is 557, similarity 0.692, Mass difference 32.028
# 1: I've marked ASLDVDMMDYSAK 97, index is 303, similarity 0.923, Mass difference 31.984
# 1: I've marked YGGYDLPDYSAPK 97, index is 305, similarity 0.769, Mass difference 16.003
# 1: I've marked SFVVDMPDYASSK 89, index is 306, similarity 0.692, Mass difference 31.971
# 4: I've marked LEADTADYAAMFK 99, index is 307, similarity 0.923, Mass difference 15.991
# 1: I've marked FDVMPYASLTTGK 97, index is 308, similarity 0.846, Mass difference 1.011
# 2: I've marked KAVMDVPDYAHAK 90, index is 298, similarity 0.846, Mass difference 0.985
# 3: I've marked QLVDDVPDYASPK 99, index is 315, similarity 0.692, Mass difference 1.005
# 3: I've marked LTVETDVSDYAHK 99, index is 562, similarity 0.692, Mass difference 32.009
# 4: I've marked QLVDDVPDYASPK 99, index is 315, similarity 0.692, Mass difference 1.005
# 4: I've marked QLVDDVPDYASPK 99, index is 315, similarity 0.692, Mass difference 31.989
# 2: I've marked ADVPDYADMSDHK 87, index is 431, similarity 0.923, Mass difference 15.993
# 1: I've marked VGEHDDLEDYAGK 98, index is 317, similarity 0.692, Mass difference 31.99
# 3: I've marked VTPGFDLEDYAAK 98, index is 194, similarity 0.692, Mass difference 21.944
# 1: I've marked VGEHDDLEDYAGK 98, index is 317, similarity 0.692, Mass difference 15.978
# 4: I've marked VGEHDDLEDYAGK 98, index is 317, similarity 0.692, Mass difference 32.07
# 2: I've marked NGGDLHDYAFKVK 93, index is 433, similarity 0.692, Mass difference 16.087
# 1: I've marked SVVSVDMPDYAHK 98, index is 320, similarity 0.692, Mass difference 0.987
# 1: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.769, Mass difference 32.111
# 1: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.692, Mass difference 22.065
# 1: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.692, Mass difference 16.099
# 4: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.692, Mass difference 15.969
# 2: I've marked SVVSVDMPDYAHK 98, index is 320, similarity 0.692, Mass difference 0.987
# 2: I've marked GDVMDYADKHLGK 86, index is 437, similarity 0.846, Mass difference 15.985
# 1: I've marked ANTVWDVDPYAAK 91, index is 332, similarity 0.692, Mass difference 21.996
# 3: I've marked VEVGVLDLEDYAK 99, index is 336, similarity 0.692, Mass difference 0.02
# 3: I've marked MVVDLQDYANVAK 99, index is 449, similarity 0.692, Mass difference 16.004
# 4: I've marked VAAKDVPDYSAWK 99, index is 335, similarity 0.692, Mass difference 0.909
# 4: I've marked VAAKDVPDYSAWK 99, index is 335, similarity 0.692, Mass difference 31.955
# 2: I've marked VVASDVQDYATWK 96, index is 604, similarity 0.692, Mass difference 31.987
# 4: I've marked VEVGVLDLEDYAK 99, index is 336, similarity 0.692, Mass difference 0.02
# 3: I've marked VAAKDVPDYSAWK 99, index is 335, similarity 0.692, Mass difference 0.909
# 3: I've marked MLDLADYALADLK 99, index is 347, similarity 0.692, Mass difference 0.081
# 4: I've marked MLDLADYALADLK 99, index is 347, similarity 0.692, Mass difference 0.081
# 2: I've marked GMRVTDLPDYTGK 89, index is 473, similarity 0.846, Mass difference 15.994
# 3: I've marked GLVADLHDYSWAK 99, index is 538, similarity 0.692, Mass difference 22.021
# 1: I've marked WSVWDVGDYAAGK 94, index is 352, similarity 0.692, Mass difference 22.042
# 3: I've marked PVADTDLEDYATK 99, index is 248, similarity 0.692, Mass difference 16.004
# 2: I've marked ETFDVPDYAEATK 89, index is 639, similarity 0.692, Mass difference 31.997
# 1: I've marked FLGYDAGPDYAHK 96, index is 355, similarity 0.692, Mass difference 22.037
# 1: I've marked RMDDYADAVGNVK 89, index is 356, similarity 0.846, Mass difference 15.991
# 1: I've marked LAANMVDYADARK 86, index is 358, similarity 0.692, Mass difference 15.908
# 1: I've marked VGPVVDLDDYAYK 97, index is 359, similarity 0.692, Mass difference 31.99
# 3: I've marked LLDFPDYAFGLAK 96, index is 484, similarity 0.692, Mass difference 16.004
# 4: I've marked WLGLDDTSDYAAK 99, index is 363, similarity 0.769, Mass difference 15.973
# 4: I've marked WLGLDDTSDYAAK 99, index is 363, similarity 0.692, Mass difference 32.034
# 1: I've marked LTDVMDYAAKEAK 98, index is 364, similarity 0.692, Mass difference 0.983
# 2: I've marked VAWNDVQDYAAPK 95, index is 553, similarity 0.692, Mass difference 21.953
# 2: I've marked LGKDLEDYSSANK 92, index is 264, similarity 0.692, Mass difference 15.933
# 4: I've marked VADQADYSAWDSK 99, index is 368, similarity 0.692, Mass difference 16.029
# 3: I've marked PLMVADYADYADK 99, index is 499, similarity 0.692, Mass difference 16.041
# 4: I've marked AFTLDDEPDYAAK 99, index is 369, similarity 0.692, Mass difference 0.957
# 4: I've marked QSLTDWADYAASK 99, index is 370, similarity 0.692, Mass difference 1.023
# 4: I've marked ETVLDVMDYAATK 99, index is 371, similarity 0.692, Mass difference 22.03
# 2: I've marked LTDVMDYAAKEAK 98, index is 364, similarity 0.692, Mass difference 0.983
# 2: I've marked TEVLDVMDYAATK 98, index is 503, similarity 0.923, Mass difference 15.994
# 1: I've marked DSWVDDTADYAAK 97, index is 373, similarity 0.692, Mass difference 31.973
# 2: I've marked MLDAPDYAQDSAK 87, index is 187, similarity 0.692, Mass difference 31.984
# 2: I've marked MLDAPDYANTDAK 93, index is 266, similarity 0.692, Mass difference 15.99
# 3: I've marked AFTLDDEPDYAAK 99, index is 369, similarity 0.692, Mass difference 0.957
# 3: I've marked DDWPDYALVADAK 99, index is 569, similarity 0.692, Mass difference 22.06
# 2: I've marked DNDVPDYADLGLK 97, index is 232, similarity 0.692, Mass difference 21.985
# 3: I've marked YGDDVQDYAQVGK 99, index is 380, similarity 0.692, Mass difference 0.997
# 3: I've marked PWDDGDLHDYAGK 99, index is 672, similarity 0.692, Mass difference 31.981
# 3: I've marked LVLFDATDYADSK 99, index is 382, similarity 0.692, Mass difference 1.022
# 3: I've marked QSLTDWADYAASK 99, index is 370, similarity 0.692, Mass difference 1.023
# 3: I've marked LVLFDATDYADSK 99, index is 382, similarity 0.692, Mass difference 1.019
# 4: I've marked YGDDVQDYAQVGK 99, index is 380, similarity 0.692, Mass difference 0.997
# 1: I've marked DGVPDYAADLYMK 85, index is 381, similarity 0.692, Mass difference 1.036
# 4: I've marked LVLFDATDYADSK 99, index is 382, similarity 0.692, Mass difference 1.022
# 4: I've marked LVLFDATDYADSK 99, index is 382, similarity 0.692, Mass difference 1.019
# 2: I've marked EGVFDLADYAMDK 85, index is 521, similarity 0.692, Mass difference 15.938
# 3: I've marked EPVQNDVADYSAK 99, index is 235, similarity 0.692, Mass difference 22.056
# 2: I've marked VTPGFDLEDYAAK 98, index is 194, similarity 0.692, Mass difference 32.039
# 3: I've marked LGSDLEDYAHTMK 99, index is 577, similarity 0.692, Mass difference 21.95
# 4: I've marked VPLGTHDLEDYAK 99, index is 384, similarity 0.692, Mass difference 22.034
# 2: I've marked QPLPNDLEDYSAK 98, index is 684, similarity 0.692, Mass difference 31.983
# 3: I've marked VSAGDMEDYAEQK 93, index is 276, similarity 0.846, Mass difference 15.991
# 2: I've marked LYLGDVPDYALNK 97, index is 597, similarity 0.692, Mass difference 22.134
# 3: I've marked TFDLQDYSAAPSK 99, index is 280, similarity 0.692, Mass difference 15.993
# 2: I've marked TYEDLADYANDGK 95, index is 527, similarity 0.692, Mass difference 15.956
# 2: I've marked ADYNEDLADYASK 98, index is 529, similarity 0.692, Mass difference 15.965
# 2: I've marked HKYGADVVDYAAK 92, index is 245, similarity 0.769, Mass difference 21.977
# 2: I've marked DGVPDYAADLYMK 85, index is 381, similarity 0.692, Mass difference 1.036
# 4: I've marked PLDLLQDAPDYAK 99, index is 394, similarity 0.692, Mass difference 0.955
# 1: I've marked HLLDQTDYAALAK 91, index is 395, similarity 0.692, Mass difference 15.968
# 3: I've marked TVTDLPDYAHSPK 99, index is 290, similarity 0.692, Mass difference 15.923
# 3: I've marked ATHELDVVDYADK 99, index is 542, similarity 0.692, Mass difference 16.041
# Step 2: 400 of 4201
# 3: I've marked FPFTSDAVDYADK 99, index is 540, similarity 0.692, Mass difference 15.998
# 2: I've marked PVSDVPDYSAQWK 98, index is 704, similarity 0.692, Mass difference 32.039
# 2: I've marked FNVPQDVPDYAVK 96, index is 706, similarity 0.692, Mass difference 32.075
# 3: I've marked PLDLLQDAPDYAK 99, index is 394, similarity 0.692, Mass difference 0.955
# 2: I've marked TAWYDGSLDYSSK 85, index is 713, similarity 0.692, Mass difference 32.027
# 3: I've marked PMPGWDATDYADK 99, index is 609, similarity 0.692, Mass difference 21.972
# 3: I've marked FGMQDSPDYAAHK 99, index is 610, similarity 0.692, Mass difference 21.984
# 3: I've marked VGWADLKDYAARK 99, index is 725, similarity 0.692, Mass difference 32.144
# 3: I've marked AYGYDLPDYADAK 99, index is 418, similarity 0.692, Mass difference 1.003
# 1: I've marked HVDLEDYAENAGK 88, index is 406, similarity 0.692, Mass difference 22.014
# 2: I've marked TGLTAKDVDYAYK 85, index is 299, similarity 0.769, Mass difference 15.957
# 2: I've marked VMQVDEDPYAAGK 96, index is 253, similarity 0.692, Mass difference 22.052
# 2: I've marked SHKLTDVQDYAGK 95, index is 422, similarity 0.692, Mass difference 1.023
# 1: I've marked VQSHLDVDDYAAK 98, index is 411, similarity 0.692, Mass difference 1.067
# 1: I've marked VQSHLDVDDYAAK 98, index is 411, similarity 0.692, Mass difference 32.032
# 2: I've marked WVPADADPYAVPK 85, index is 208, similarity 0.692, Mass difference 31.994
# 2: I've marked HVAWDLGADYAVK 91, index is 297, similarity 0.692, Mass difference 15.989
# 1: I've marked MFSVADKADYAVK 93, index is 412, similarity 0.692, Mass difference 22.015
# 1: I've marked MFSVADKADYAVK 93, index is 412, similarity 0.692, Mass difference 31.989
# 2: I've marked LAHLPDKSDYAAK 85, index is 209, similarity 0.692, Mass difference 31.972
# 1: I've marked HGGLPDKPDYAYK 92, index is 413, similarity 0.692, Mass difference 31.951
# 3: I've marked LEADTADYAAMFK 99, index is 307, similarity 0.923, Mass difference 15.991
# 2: I've marked YGGYDLPDYSAPK 97, index is 305, similarity 0.769, Mass difference 16.003
# 4: I've marked AYGYDLPDYADAK 99, index is 418, similarity 0.692, Mass difference 1.003
# 4: I've marked AYGYDLPDYADAK 99, index is 418, similarity 0.692, Mass difference 16.026
# 4: I've marked AYGYDLPDYADAK 99, index is 418, similarity 0.692, Mass difference 32.024
# 4: I've marked AYGYDLPDYADAK 99, index is 418, similarity 0.692, Mass difference 32.026
# 1: I've marked LNHNVDVSDYASK 92, index is 419, similarity 0.692, Mass difference 16.021
# 1: I've marked SHKLTDVQDYAGK 95, index is 422, similarity 0.692, Mass difference 31.999
# 2: I've marked VQSHLDVDDYAAK 98, index is 411, similarity 0.692, Mass difference 1.067
# 2: I've marked MMDHVDYASALPK 97, index is 728, similarity 0.692, Mass difference 31.902
# 2: I've marked YGQFSDVADYADK 94, index is 566, similarity 0.692, Mass difference 16.053
# 3: I've marked KPTEDVTDYADPK 99, index is 571, similarity 0.692, Mass difference 16.033
# 1: I've marked VPAEMPDVQDSFK 86, index is 429, similarity 0.846, Mass difference 15.996
# 3: I've marked PLVDPDLADYANK 99, index is 215, similarity 0.692, Mass difference 32.039
# 2: I've marked YPWALDAADYAGK 95, index is 268, similarity 0.692, Mass difference 22.081
# 3: I've marked WGSLTDLTDYAAK 99, index is 270, similarity 0.692, Mass difference 22.056
# 3: I've marked WSATEDLADYADK 99, index is 627, similarity 0.692, Mass difference 21.897
# 1: I've marked ADVPDYADMSDHK 87, index is 431, similarity 0.923, Mass difference 15.993
# 4: I've marked FVGDHPDYAEVSK 99, index is 432, similarity 0.692, Mass difference 32.04
# 2: I've marked FVEDTDPYAVDSK 97, index is 638, similarity 0.692, Mass difference 21.987
# 1: I've marked NGGDLHDYAFKVK 93, index is 433, similarity 0.692, Mass difference 16.087
# 3: I've marked LVGGLFDLHDYAK 93, index is 322, similarity 0.692, Mass difference 15.969
# 1: I've marked NGGDLHDYAFKVK 93, index is 433, similarity 0.692, Mass difference 0.987
# 1: I've marked SGETNHDVEDYAK 85, index is 435, similarity 0.692, Mass difference 1.049
# 1: I've marked SGETNHDVEDYAK 85, index is 435, similarity 0.692, Mass difference 22.029
# 1: I've marked GDVMDYADKHLGK 86, index is 437, similarity 0.846, Mass difference 15.985
# 2: I've marked EQDVQDYAGLQSK 93, index is 589, similarity 0.692, Mass difference 16.02
# 1: I've marked LAAYMQHDVMAAK 85, index is 440, similarity 0.692, Mass difference 22.063
# 2: I've marked NGGDLHDYAFKVK 93, index is 433, similarity 0.692, Mass difference 0.987
# 2: I've marked SGETNHDVEDYAK 85, index is 435, similarity 0.692, Mass difference 1.049
# 3: I've marked HSVVDVPDYADHK 99, index is 603, similarity 0.769, Mass difference 15.986
# 2: I've marked VVASDVQDYATWK 96, index is 604, similarity 0.692, Mass difference 16.017
# 4: I've marked MVVDLQDYANVAK 99, index is 449, similarity 0.692, Mass difference 16.004
# 4: I've marked MVVDLQDYANVAK 99, index is 449, similarity 0.692, Mass difference 31.987
# 4: I've marked MVVDLQDYANVAK 99, index is 449, similarity 0.692, Mass difference 32.02
# 4: I've marked MNALDKQDYAAVK 99, index is 457, similarity 0.923, Mass difference 15.992
# 3: I've marked QMADTQDYAAKLK 99, index is 808, similarity 0.692, Mass difference 31.991
# 4: I've marked PTDLKDYADTSLK 99, index is 458, similarity 0.692, Mass difference 32.005
# 4: I've marked SPAVHHDVEDYAK 99, index is 463, similarity 0.692, Mass difference 21.983
# 1: I've marked QDLEDYARTSAAK 97, index is 465, similarity 0.692, Mass difference 22.006
# 2: I've marked KPHEGLDVPDYAK 97, index is 475, similarity 0.692, Mass difference 1.007
# 3: I've marked FGTGPDVKDYAWK 99, index is 619, similarity 0.692, Mass difference 15.989
# 1: I've marked QGVHYDMADYAAK 91, index is 468, similarity 0.692, Mass difference 16.051
# 1: I've marked QGVHYDMADYAAK 91, index is 468, similarity 0.692, Mass difference 22.063
# 2: I've marked FGAVSDQVDYAFK 97, index is 313, similarity 0.692, Mass difference 22.014
# 2: I've marked LRNDLKDYAGTPK 96, index is 696, similarity 0.692, Mass difference 22.095
# 1: I've marked GMRVTDLPDYTGK 89, index is 473, similarity 0.846, Mass difference 15.994
# 2: I've marked EGLDVQDYAFSEK 94, index is 831, similarity 0.692, Mass difference 31.949
# 2: I've marked HKYGADVVDYAAK 92, index is 245, similarity 0.769, Mass difference 32.063
# 2: I've marked LAANMVDYADARK 86, index is 358, similarity 0.692, Mass difference 15.908
# 2: I've marked RMDDYADAVGNVK 89, index is 356, similarity 0.846, Mass difference 15.991
# 1: I've marked DMRDYADAVGNVK 91, index is 479, similarity 0.692, Mass difference 31.954
# 2: I've marked MGADLHDYAAFMK 98, index is 843, similarity 0.769, Mass difference 31.94
# 4: I've marked LLDFPDYAFGLAK 96, index is 484, similarity 0.692, Mass difference 16.004
# 3: I've marked WLGLDDTSDYAAK 99, index is 363, similarity 0.769, Mass difference 15.973
# 2: I've marked MPFSDAPDYADNK 92, index is 647, similarity 0.692, Mass difference 15.927
# 3: I've marked AAEQDVFDYADDK 99, index is 649, similarity 0.692, Mass difference 15.925
# 3: I've marked AFGGEDVEDYAWK 99, index is 652, similarity 0.692, Mass difference 15.942
# 4: I've marked YDMDVADYASGHK 99, index is 492, similarity 0.692, Mass difference 22.057
# 1: I've marked MGLPTDHHDYAAK 93, index is 494, similarity 0.692, Mass difference 32.02
# 2: I've marked FGLPTDHHDYAAK 90, index is 504, similarity 0.923, Mass difference 0.031
# 3: I've marked VADQADYSAWDSK 99, index is 368, similarity 0.692, Mass difference 16.029
# 3: I've marked PLMVADYADYADK 99, index is 499, similarity 0.692, Mass difference 0.012
# 3: I've marked FGSDLLDYADPMK 99, index is 498, similarity 0.923, Mass difference 0.001
# 3: I've marked SFYGSDLLDYADK 99, index is 730, similarity 0.769, Mass difference 22.003
# 3: I've marked FSYGSDLLDYADK 99, index is 731, similarity 0.769, Mass difference 22.005
# 4: I've marked FGSDLLDYADPMK 99, index is 498, similarity 0.923, Mass difference 0.001
# 3: I've marked SFYGSDLLDYADK 99, index is 730, similarity 0.846, Mass difference 22.003
# 3: I've marked FSYGSDLLDYADK 99, index is 731, similarity 0.846, Mass difference 22.004
# 4: I've marked PLMVADYADYADK 99, index is 499, similarity 0.692, Mass difference 16.041
# 4: I've marked PLMVADYADYADK 99, index is 499, similarity 0.692, Mass difference 0.012
# 2: I've marked LAKGNDVYDYADK 86, index is 507, similarity 0.692, Mass difference 0.031
# Step 2: 500 of 4201
# 4: I've marked DLHDYADATSHVK 99, index is 501, similarity 0.692, Mass difference 0.013
# 3: I've marked DLHDYAHATVFSK 99, index is 874, similarity 0.769, Mass difference 32.043
# 3: I've marked DLHDYADATSHVK 99, index is 501, similarity 0.692, Mass difference 0.013
# 4: I've marked DLEDYSATPSVFK 99, index is 502, similarity 0.692, Mass difference 0.992
# 3: I've marked DLHDYAHATVFSK 99, index is 874, similarity 0.692, Mass difference 32.03
# 2: I've marked ANTVWDVDPYAAK 91, index is 332, similarity 0.692, Mass difference 21.996
# 1: I've marked TEVLDVMDYAATK 98, index is 503, similarity 0.923, Mass difference 15.994
# 3: I've marked MVDVMDYASAENK 98, index is 509, similarity 0.692, Mass difference 0.944
# 1: I've marked TEVLDVMDYAATK 98, index is 503, similarity 0.692, Mass difference 22.102
# 1: I've marked FGLPTDHHDYAAK 90, index is 504, similarity 0.692, Mass difference 32.05
# 1: I've marked FGLPTDHHDYAAK 90, index is 504, similarity 0.923, Mass difference 0.031
# 5: I've marked LVDVPDYALAQRK 99, index is 671, similarity 0.692, Mass difference 16.02
# 4: I've marked MVDVMDYASAENK 98, index is 509, similarity 0.692, Mass difference 0.944
# 2: I've marked QMVVMDLGDYAAK 97, index is 513, similarity 0.692, Mass difference 0.031
# 2: I've marked QVLDKQDYASAEK 95, index is 751, similarity 0.692, Mass difference 22.102
# 1: I've marked TMEKDLEDYAGGK 95, index is 512, similarity 0.692, Mass difference 22.024
# 1: I've marked QMVVMDLGDYAAK 97, index is 513, similarity 0.692, Mass difference 0.031
# 1: I've marked ASPLADMQDYAYK 98, index is 514, similarity 0.692, Mass difference 16.005
# 2: I've marked AFSAVDMRDYADK 94, index is 883, similarity 0.692, Mass difference 32.002
# 2: I've marked LHLGGDTHDYAFK 95, index is 523, similarity 0.692, Mass difference 0.965
# 1: I've marked MEDVPDYSSMDGK 93, index is 518, similarity 0.692, Mass difference 0.028
# 2: I've marked MEDVPDYSSMDGK 93, index is 518, similarity 0.692, Mass difference 0.028
# 2: I've marked PHAMTDVPDYAEK 98, index is 522, similarity 0.692, Mass difference 0.045
# 1: I've marked EGVFDLADYAMDK 85, index is 521, similarity 0.692, Mass difference 31.969
# 1: I've marked EGVFDLADYAMDK 85, index is 521, similarity 0.692, Mass difference 15.938
# 1: I've marked EGVFDLADYAMDK 85, index is 521, similarity 0.692, Mass difference 0.974
# 1: I've marked PHAMTDVPDYAEK 98, index is 522, similarity 0.692, Mass difference 0.045
# 1: I've marked LHLGGDTHDYAFK 95, index is 523, similarity 0.692, Mass difference 0.965
# 3: I've marked LVVHDVPDYSSFK 99, index is 906, similarity 0.692, Mass difference 32.042
# 3: I've marked VPKVGDWVDYAEK 99, index is 907, similarity 0.692, Mass difference 32.047
# 1: I've marked TYEDLADYANDGK 95, index is 527, similarity 0.692, Mass difference 15.956
# 2: I've marked EGVFDLADYAMDK 85, index is 521, similarity 0.692, Mass difference 0.974
# 1: I've marked TYEDLADYANDGK 95, index is 527, similarity 0.692, Mass difference 0.009
# 1: I've marked TYEDLADYANDGK 95, index is 527, similarity 0.692, Mass difference 16.037
# 3: I've marked VNSYADTLDYADK 99, index is 532, similarity 0.692, Mass difference 0.039
# 1: I've marked ADYNEDLADYASK 98, index is 529, similarity 0.692, Mass difference 15.965
# 2: I've marked TYEDLADYANDGK 95, index is 527, similarity 0.692, Mass difference 0.009
# 2: I've marked YVNFPDTADYASK 96, index is 689, similarity 0.692, Mass difference 16.045
# 4: I've marked VNSYADTLDYADK 99, index is 532, similarity 0.692, Mass difference 15.973
# 1: I've marked STHPQDVVDYADK 96, index is 533, similarity 0.923, Mass difference 0.004
# 1: I've marked STHPQDVVDYADK 96, index is 533, similarity 0.769, Mass difference 1.025
# 2: I've marked STHPQDVVDYADK 96, index is 533, similarity 0.923, Mass difference 0.004
# 4: I've marked TSHPQDVVDYADK 99, index is 535, similarity 0.692, Mass difference 0.987
# 3: I've marked ATHELDVVDYADK 99, index is 542, similarity 0.769, Mass difference 1.021
# 2: I've marked HLLDQTDYAALAK 91, index is 395, similarity 0.692, Mass difference 15.968
# 1: I've marked HVLLGDWSDYAAK 95, index is 537, similarity 0.692, Mass difference 15.964
# 1: I've marked HVLLGDWSDYAAK 95, index is 537, similarity 0.692, Mass difference 15.965
# 4: I've marked GLVADLHDYSWAK 99, index is 538, similarity 0.692, Mass difference 22.021
# 4: I've marked GLVADLHDYSWAK 99, index is 538, similarity 0.692, Mass difference 31.953
# 1: I've marked NADHAQDVEDYAK 92, index is 539, similarity 0.692, Mass difference 16.086
# 1: I've marked NADHAQDVEDYAK 92, index is 539, similarity 0.692, Mass difference 32.004
# 4: I've marked FPFTSDAVDYADK 99, index is 540, similarity 0.692, Mass difference 15.998
# 3: I've marked TSHPQDVVDYADK 99, index is 535, similarity 0.692, Mass difference 0.987
# 3: I've marked MPVTEDVHDYAAK 99, index is 702, similarity 0.692, Mass difference 16.007
# 2: I've marked SNTNDVPDYAFHK 98, index is 928, similarity 0.692, Mass difference 32.006
# 4: I've marked ATHELDVVDYADK 99, index is 542, similarity 0.692, Mass difference 16.041
# 2: I've marked STHPQDVVDYADK 96, index is 533, similarity 0.769, Mass difference 1.025
# 4: I've marked ATHELDVVDYADK 99, index is 542, similarity 0.769, Mass difference 1.021
# 4: I've marked ATHELDVVDYADK 99, index is 542, similarity 0.692, Mass difference 21.973
# 1: I've marked HALDDWGADYADK 87, index is 547, similarity 0.692, Mass difference 31.917
# 1: I've marked VDKMDYADGATYK 91, index is 548, similarity 0.846, Mass difference 15.99
# 1: I've marked GLWNDVQDYAAPK 96, index is 550, similarity 0.692, Mass difference 32.087
# 2: I've marked VAWNDVQDYAAPK 95, index is 553, similarity 0.846, Mass difference 0.007
# 1: I've marked RGFTDVADYAAYK 97, index is 551, similarity 0.692, Mass difference 16.021
# 4: I've marked SNLLHDLMDYAGK 99, index is 552, similarity 0.692, Mass difference 22.152
# 1: I've marked VAWNDVQDYAAPK 95, index is 553, similarity 0.692, Mass difference 21.953
# 1: I've marked VAWNDVQDYAAPK 95, index is 553, similarity 0.846, Mass difference 0.007
# 2: I've marked ASLDVDMMDYSAK 97, index is 303, similarity 0.923, Mass difference 31.984
# 1: I've marked EYGMVDAEDYTGK 94, index is 557, similarity 0.692, Mass difference 32.028
# 1: I've marked EYGMVDAEDYTGK 94, index is 557, similarity 0.846, Mass difference 15.988
# 2: I've marked SFVVDMPDYASSK 89, index is 306, similarity 0.692, Mass difference 31.971
# 2: I've marked SFYDLEDYANGGK 98, index is 564, similarity 0.692, Mass difference 1.011
# 3: I've marked SFYGSDLLDYADK 99, index is 730, similarity 0.692, Mass difference 16.048
# 2: I've marked DFSFSDLADYDSK 98, index is 955, similarity 0.692, Mass difference 32.003
# 3: I've marked AYGYDLPDYADAK 99, index is 418, similarity 0.692, Mass difference 16.026
# 4: I've marked VYDLFDYADTAGK 99, index is 560, similarity 0.692, Mass difference 22.028
# 4: I've marked LTVETDVSDYAHK 99, index is 562, similarity 0.692, Mass difference 32.009
# 2: I've marked LNHNVDVSDYASK 92, index is 419, similarity 0.692, Mass difference 16.021
# 1: I've marked SFYDLEDYANGGK 98, index is 564, similarity 0.692, Mass difference 1.011
# 4: I've marked SFYDLEDYANGGK 98, index is 564, similarity 0.692, Mass difference 1.061
# 1: I've marked YGQFSDVADYADK 94, index is 566, similarity 0.692, Mass difference 16.053
# 1: I've marked LDAPDYADNNWGK 91, index is 567, similarity 0.692, Mass difference 32.016
# 1: I've marked MLDVEDYSHGGQK 89, index is 568, similarity 0.692, Mass difference 1.046
# 4: I've marked DDWPDYALVADAK 99, index is 569, similarity 0.692, Mass difference 22.06
# 2: I've marked VPAEMPDVQDSFK 86, index is 429, similarity 0.846, Mass difference 15.996
# 4: I've marked KPTEDVTDYADPK 99, index is 571, similarity 0.692, Mass difference 16.033
# 3: I've marked QLVDDVPDYASPK 99, index is 315, similarity 0.692, Mass difference 31.989
# 2: I've marked QVLDKQDYASAEK 95, index is 751, similarity 0.692, Mass difference 16.039
# 3: I've marked TFKLPDLPDYASK 99, index is 754, similarity 0.692, Mass difference 16.084
# 4: I've marked VLDDLDQPDYASK 99, index is 572, similarity 0.769, Mass difference 32.041
# 2: I've marked RDVSADMHDYAAK 88, index is 744, similarity 0.692, Mass difference 15.953
# 4: I've marked LGSDLEDYAHTMK 99, index is 577, similarity 0.692, Mass difference 21.95
# 3: I've marked VGEHDDLEDYAGK 98, index is 317, similarity 0.692, Mass difference 32.07
# 3: I've marked SFYDLEDYANGGK 98, index is 564, similarity 0.692, Mass difference 1.061
# 2: I've marked MLDVEDYSHGGQK 89, index is 568, similarity 0.692, Mass difference 1.046
# 1: I've marked LDDLEDYAGGRQK 98, index is 579, similarity 0.692, Mass difference 1.039
# 1: I've marked FDVPDYADPKQGK 97, index is 580, similarity 0.692, Mass difference 31.993
# 2: I've marked LTHDTVHDYADSK 86, index is 848, similarity 0.692, Mass difference 21.963
# 3: I've marked LNTFNDVPDYADK 99, index is 988, similarity 0.692, Mass difference 31.975
# 1: I've marked VGVVWDTQDYAVK 86, index is 583, similarity 0.692, Mass difference 31.936
# 3: I've marked VPLGTHDLEDYAK 99, index is 384, similarity 0.692, Mass difference 22.034
# 2: I've marked GTVWDEDPYASLK 86, index is 590, similarity 0.692, Mass difference 0.932
# 3: I've marked WMMPGDADPYADK 99, index is 771, similarity 0.692, Mass difference 16.003
# 3: I've marked MLDKEDYAVTAPK 99, index is 594, similarity 0.692, Mass difference 0.058
# 3: I've marked LMDKEDYAVTAPK 99, index is 785, similarity 0.692, Mass difference 16.052
# 1: I've marked EQDVQDYAGLQSK 93, index is 589, similarity 0.692, Mass difference 16.02
# 1: I've marked GTVWDEDPYASLK 86, index is 590, similarity 0.692, Mass difference 0.932
# 1: I've marked GTVWDEDPYASLK 86, index is 590, similarity 0.692, Mass difference 31.94
# 1: I've marked GTVWDEDPYASLK 86, index is 590, similarity 0.692, Mass difference 32.037
# 2: I've marked VVQTDWADYAVSK 98, index is 605, similarity 0.692, Mass difference 1.002
# 4: I've marked MLDKEDYAVTAPK 99, index is 594, similarity 0.692, Mass difference 0.058
# 4: I've marked MLDKEDYAVTAPK 99, index is 594, similarity 0.923, Mass difference 15.994
# 3: I've marked FDMKDYADVASPK 99, index is 862, similarity 0.692, Mass difference 21.95
# 2: I've marked VVASDVQDYATWK 96, index is 604, similarity 0.692, Mass difference 0.984
# 2: I've marked LDDLEDYAGGRQK 98, index is 579, similarity 0.692, Mass difference 1.039
# 1: I've marked LYLGDVPDYALNK 97, index is 597, similarity 0.692, Mass difference 22.134
# 1: I've marked LYLGDVPDYALNK 97, index is 597, similarity 0.692, Mass difference 31.928
# 1: I've marked LYLGDVPDYALNK 97, index is 597, similarity 0.692, Mass difference 31.964
# 1: I've marked GEHSFDTPDYADK 88, index is 598, similarity 0.692, Mass difference 0.076
# 1: I've marked GEHSFDTPDYADK 88, index is 598, similarity 0.692, Mass difference 16.056
# Step 2: 600 of 4201
# 3: I've marked VAAKDVPDYSAWK 99, index is 335, similarity 0.692, Mass difference 31.955
# 4: I've marked NAMDKDVPDYAVK 99, index is 602, similarity 0.692, Mass difference 1.03
# 4: I've marked HSVVDVPDYADHK 99, index is 603, similarity 0.769, Mass difference 15.986
# 2: I've marked GEHSFDTPDYADK 88, index is 598, similarity 0.692, Mass difference 0.076
# 1: I've marked VVASDVQDYATWK 96, index is 604, similarity 0.692, Mass difference 31.987
# 1: I've marked VVASDVQDYATWK 96, index is 604, similarity 0.692, Mass difference 16.017
# 1: I've marked VVASDVQDYATWK 96, index is 604, similarity 0.692, Mass difference 0.984
# 1: I've marked VVQTDWADYAVSK 98, index is 605, similarity 0.692, Mass difference 1.002
# 4: I've marked LVDLPDYAAVFMK 99, index is 606, similarity 0.692, Mass difference 16.056
# 3: I've marked DLHDYAHATVFSK 99, index is 874, similarity 0.692, Mass difference 21.956
# 4: I've marked VLLADTHDYAVHK 99, index is 607, similarity 0.692, Mass difference 31.972
# 4: I've marked PMPGWDATDYADK 99, index is 609, similarity 0.692, Mass difference 21.972
# 2: I've marked MLPLGDTQDYAHK 86, index is 887, similarity 0.692, Mass difference 22.091
# 2: I've marked AEPMMDTQDYADK 98, index is 1034, similarity 0.692, Mass difference 31.994
# 4: I've marked FGMQDSPDYAAHK 99, index is 610, similarity 0.692, Mass difference 21.984
# 2: I've marked MFSVADKADYAVK 93, index is 412, similarity 0.692, Mass difference 22.015
# 3: I've marked MNALDKQDYAAVK 99, index is 457, similarity 0.923, Mass difference 15.992
# 3: I've marked NAMDKDVPDYAVK 99, index is 602, similarity 0.692, Mass difference 1.03
# 3: I've marked LDFDKQDYAAVAK 99, index is 621, similarity 0.769, Mass difference 1.019
# 3: I've marked QMADTQDYAAKLK 99, index is 808, similarity 0.692, Mass difference 15.999
# 3: I've marked FAFSNDKQDYAAK 99, index is 886, similarity 0.692, Mass difference 21.982
# 3: I've marked LQDLADYSDYPAK 99, index is 806, similarity 0.692, Mass difference 15.936
# 3: I've marked LAQHDMADYAEPK 99, index is 882, similarity 0.692, Mass difference 21.906
# 2: I've marked KASDLDRMDYAAK 85, index is 821, similarity 0.692, Mass difference 16.089
# ...
# 2: I've marked FVMDDKHDYARYK 92, index is 3806, similarity 0.769, Mass difference 0.927
# 3: I've marked MFVDTHDYAYMEK 99, index is 3600, similarity 0.692, Mass difference 22.064
# 2: I've marked DTDWHDYAFYQFK 98, index is 3983, similarity 0.769, Mass difference 31.992
# 1: I've marked FVMDDKHDYARYK 92, index is 3806, similarity 0.692, Mass difference 22.099
# 2: I've marked FVMDDKHDYAYRK 87, index is 3669, similarity 0.923, Mass difference 15.995
# 1: I've marked FVMDDKHDYARYK 92, index is 3806, similarity 0.769, Mass difference 0.927
# 1: I've marked MRSFWDKKDYAEK 88, index is 3807, similarity 0.692, Mass difference 31.96
# 1: I've marked KWMFDDQEDYAEK 93, index is 3809, similarity 0.692, Mass difference 21.983
# 1: I've marked KWMFDDQEDYAEK 93, index is 3809, similarity 0.692, Mass difference 16.065
# 2: I've marked WFVHDMEDYAMRK 89, index is 3944, similarity 0.692, Mass difference 22.01
# 4: I've marked ADWEDYAQKHEWK 97, index is 3817, similarity 0.692, Mass difference 31.981
# 1: I've marked YLNYFDLKDYSHK 94, index is 3819, similarity 0.692, Mass difference 32.035
# 2: I've marked YYDVADYAFWEHK 86, index is 3823, similarity 0.692, Mass difference 0.035
# 1: I've marked YYDVADYAFWEHK 86, index is 3823, similarity 0.692, Mass difference 0.035
# 1: I've marked YYDVADYAFWEHK 86, index is 3823, similarity 0.692, Mass difference 0.066
# 2: I've marked YYDVADYAFWEHK 86, index is 3823, similarity 0.692, Mass difference 0.066
# 1: I've marked MNDYWDYASDHYK 89, index is 3828, similarity 0.692, Mass difference 0.066
# 2: I've marked MNDYWDYASDHYK 89, index is 3828, similarity 0.692, Mass difference 0.066
# 4: I've marked YWRYLDDEDYAAK 99, index is 3833, similarity 0.692, Mass difference 22.045
# 3: I've marked YVWYRDKNDYAAK 99, index is 3701, similarity 0.692, Mass difference 15.943
# 1: I've marked RLMHFDWPDYAEK 94, index is 3834, similarity 0.692, Mass difference 32.03
# 3: I've marked WRMDLHDYSHQDK 99, index is 3969, similarity 0.692, Mass difference 21.964
# 3: I've marked YLDMHDYSFHRLK 99, index is 4005, similarity 0.692, Mass difference 32.017
# 1: I've marked RTWRKDLEDYAQK 90, index is 3843, similarity 0.692, Mass difference 16.004
# 1: I've marked WVDRHDYANYDEK 97, index is 3852, similarity 0.692, Mass difference 31.854
# 1: I've marked WVDRHDYANYDEK 97, index is 3852, similarity 0.692, Mass difference 15.976
# 2: I've marked FSEDQHDYSEFYK 92, index is 3721, similarity 0.692, Mass difference 16.079
# 2: I've marked WSWDVDTRDYAWK 98, index is 3947, similarity 0.692, Mass difference 16.013
# 2: I've marked KSYDLQDYSYRNK 98, index is 3583, similarity 0.692, Mass difference 32.021
# 1: I've marked YFLWDLHDYALQK 97, index is 3863, similarity 0.692, Mass difference 16.135
# 2: I've marked WDWVMDPRDYSDK 89, index is 3866, similarity 0.846, Mass difference 0.001
# 1: I've marked WDWVMDPRDYSDK 89, index is 3866, similarity 0.846, Mass difference 0.001
# 1: I've marked FDYWFDFPDYAVK 93, index is 3867, similarity 0.692, Mass difference 21.974
# 3: I've marked FWWSDTQDYASFK 99, index is 3591, similarity 0.692, Mass difference 32.07
# 2: I've marked WWDDKQDYATQLK 90, index is 3752, similarity 0.769, Mass difference 16.003
# 2: I've marked MYTVYDMEDYAHK 91, index is 3601, similarity 0.692, Mass difference 32.012
# 1: I've marked QYYTDMDEDYARK 95, index is 3872, similarity 0.692, Mass difference 1.049
# 2: I've marked EQAYWQDMEDYAK 97, index is 3704, similarity 0.692, Mass difference 22.071
# 2: I've marked QYYTDMDEDYARK 95, index is 3872, similarity 0.692, Mass difference 1.049
# 2: I've marked YFDQHDYAENPRK 92, index is 3616, similarity 0.692, Mass difference 32.007
# 2: I've marked MYKDLYDYADKYK 96, index is 3884, similarity 0.692, Mass difference 1.038
# 2: I've marked WRYYDLGDYAEHK 92, index is 3882, similarity 0.692, Mass difference 0.048
# 1: I've marked WRYYDLGDYAEHK 92, index is 3882, similarity 0.692, Mass difference 0.048
# 1: I've marked MYKDLYDYADKYK 96, index is 3884, similarity 0.692, Mass difference 22.03
# 2: I've marked MYKEQSYYADKYK 86, index is 3886, similarity 0.769, Mass difference 0.998
# 1: I've marked MYKDLYDYADKYK 96, index is 3884, similarity 0.923, Mass difference 15.994
# 3: I've marked HLTWQWDREDYAK 99, index is 4036, similarity 0.692, Mass difference 31.983
# 1: I've marked MYKEQSYYADKYK 86, index is 3886, similarity 0.769, Mass difference 0.998
# 4: I've marked TFLDQHDYAHRWK 99, index is 3887, similarity 0.692, Mass difference 32.05
# 2: I've marked WEDMTDWQDYANK 93, index is 3789, similarity 0.923, Mass difference 15.991
# 1: I've marked YFYFDMHDYASDK 96, index is 3889, similarity 0.692, Mass difference 31.979
# 1: I've marked YFYFDMHDYASDK 96, index is 3889, similarity 0.692, Mass difference 31.911
# 1: I've marked YFYFDMHDYASDK 96, index is 3889, similarity 0.846, Mass difference 21.97
# 1: I've marked YFYFDMHDYASDK 96, index is 3889, similarity 0.692, Mass difference 0.125
# 1: I've marked YFYFDMHDYASDK 96, index is 3889, similarity 0.692, Mass difference 22.072
# 3: I've marked YWEFKDLHDYAAK 99, index is 3655, similarity 0.692, Mass difference 32.01
# 2: I've marked YFYFDMHDYASDK 96, index is 3889, similarity 0.692, Mass difference 0.125
# 1: I've marked KYEDDDMMDYAYK 88, index is 3895, similarity 0.769, Mass difference 31.978
# 1: I've marked LRMFQDMRDYAEK 90, index is 3898, similarity 0.692, Mass difference 22.025
# 3: I've marked VFWYDRPDYADQK 99, index is 3801, similarity 0.692, Mass difference 16.025
# Step 2: 3900 of 4201
# 2: I've marked FDQHDYAYARFHK 97, index is 3760, similarity 0.692, Mass difference 22.011
# 3: I've marked WEEFDTHDYAFTK 99, index is 3674, similarity 0.692, Mass difference 32.05
# 3: I've marked WLKRGDYHDYAFK 99, index is 3771, similarity 0.692, Mass difference 21.934
# 2: I've marked KWMFDDQEDYAEK 93, index is 3809, similarity 0.692, Mass difference 16.065
# 2: I've marked WDWPDYAHFRAYK 88, index is 4062, similarity 0.692, Mass difference 32.057
# 2: I've marked ELFHYDPRDYAMK 98, index is 3784, similarity 0.692, Mass difference 22.005
# 2: I've marked HFQYEDQTDYSYK 88, index is 3919, similarity 0.692, Mass difference 0.943
# 1: I've marked MVKYTDWRDYSDK 92, index is 3917, similarity 0.692, Mass difference 31.993
# 1: I've marked MVKYTDWRDYSDK 92, index is 3917, similarity 0.692, Mass difference 31.991
# 2: I've marked KYMLDWPDYSDMK 88, index is 3921, similarity 0.692, Mass difference 0.954
# 1: I've marked HFQYEDQTDYSYK 88, index is 3919, similarity 0.692, Mass difference 0.943
# 1: I've marked KYMLDWPDYSDMK 88, index is 3921, similarity 0.692, Mass difference 0.954
# 4: I've marked WVFDKHDYSHDFK 99, index is 3923, similarity 0.692, Mass difference 32.05
# 2: I've marked RTWRKDLEDYAQK 90, index is 3843, similarity 0.692, Mass difference 15.887
# 3: I've marked YTEHWDYEDYAHK 99, index is 4066, similarity 0.692, Mass difference 31.955
# 1: I've marked WEEDWEDYAVRVK 93, index is 3929, similarity 0.692, Mass difference 0.959
# 2: I've marked RMAFKDWFDYADK 93, index is 3706, similarity 0.692, Mass difference 32.028
# 3: I've marked FDRFDYADYRNMK 99, index is 4069, similarity 0.692, Mass difference 31.89
# 2: I've marked WEEDWEDYAVRVK 93, index is 3929, similarity 0.692, Mass difference 0.959
# 2: I've marked VSQEYDYQDYAWK 93, index is 3724, similarity 0.692, Mass difference 32.034
# 1: I've marked WFVHDMEDYAMRK 89, index is 3944, similarity 0.692, Mass difference 22.01
# 1: I've marked WFVHDMEDYAMRK 89, index is 3944, similarity 0.692, Mass difference 21.968
# 1: I've marked VWYAHDHHDYAWK 98, index is 3945, similarity 0.692, Mass difference 0.014
# 2: I've marked WSWDVDVSYWAWK 89, index is 3948, similarity 0.769, Mass difference 0.001
# 1: I've marked WSWDVDVSYWAWK 89, index is 3948, similarity 0.769, Mass difference 0.001
# 2: I've marked VWYAHDHHDYAWK 98, index is 3945, similarity 0.692, Mass difference 0.014
# 2: I've marked KWYNKDLVDYAWK 96, index is 3959, similarity 0.692, Mass difference 1.081
# 2: I've marked MRVMHDVHDYSFK 98, index is 3746, similarity 0.692, Mass difference 31.904
# 1: I've marked KYQYMDKPDYAYK 96, index is 3955, similarity 0.692, Mass difference 32.02
# 4: I've marked RWDLQDYAWYQGK 98, index is 3956, similarity 0.692, Mass difference 16.063
# 2: I've marked RWFNFDRKDYADK 92, index is 4077, similarity 0.692, Mass difference 32.025
# 1: I've marked KWYNKDLVDYAWK 96, index is 3959, similarity 0.692, Mass difference 1.081
# 4: I've marked WYWNQDVPDYSEK 99, index is 3962, similarity 0.692, Mass difference 32.048
# 2: I've marked NFDQHDYAHRDWK 92, index is 3972, similarity 0.692, Mass difference 1.008
# 4: I've marked WRMDLHDYSHQDK 99, index is 3969, similarity 0.692, Mass difference 21.964
# 2: I've marked WNMFQDLHDYAYK 98, index is 4026, similarity 0.692, Mass difference 15.933
# 1: I've marked NFDQHDYAHRDWK 92, index is 3972, similarity 0.692, Mass difference 1.008
# 2: I've marked MYKDLYDYADKYK 96, index is 3884, similarity 0.923, Mass difference 15.994
# 1: I've marked WNDMHDYSHMLRK 90, index is 3976, similarity 0.769, Mass difference 16.037
# 4: I've marked YEHDWEDYASYEK 99, index is 3980, similarity 0.692, Mass difference 22.027
# 1: I've marked DTDWHDYAFYQFK 98, index is 3983, similarity 0.769, Mass difference 31.992
# 2: I've marked MRSFWDKKDYAEK 88, index is 3807, similarity 0.692, Mass difference 31.96
# 1: I've marked YDALNWDVMYYRK 85, index is 3990, similarity 0.769, Mass difference 15.994
# 3: I've marked ADWEDYAQKHEWK 97, index is 3817, similarity 0.692, Mass difference 31.981
# 1: I've marked YAEVYDWEDYAWK 97, index is 3992, similarity 0.692, Mass difference 32.042
# 2: I've marked EYHSQDWQDYAWK 98, index is 4064, similarity 0.692, Mass difference 16.04
# 2: I've marked ENYDKHDYAFWRK 98, index is 4111, similarity 0.692, Mass difference 32.11
# Step 2: 4000 of 4201
# 5: I've marked WLWNNDWHDYADK 99, index is 4084, similarity 0.692, Mass difference 21.977
# 4: I've marked TMWLWDQHDYAFK 99, index is 4002, similarity 0.769, Mass difference 32.055
# 4: I've marked YLDMHDYSFHRLK 99, index is 4005, similarity 0.692, Mass difference 32.017
# 2: I've marked NRDDMHDYSYFRK 86, index is 4083, similarity 0.692, Mass difference 21.941
# 2: I've marked FRSMYDMPDYSWK 88, index is 4071, similarity 0.846, Mass difference 15.994
# 2: I've marked MYWHDRHDYARAK 91, index is 4090, similarity 0.692, Mass difference 21.979
# 3: I've marked RWDLQDYAWYQGK 98, index is 3956, similarity 0.692, Mass difference 16.063
# 2: I've marked FRKWDTRDYAYPK 92, index is 4024, similarity 0.846, Mass difference 1.001
# 4: I've marked RWQYDLEDYAQMK 93, index is 4022, similarity 0.692, Mass difference 21.972
# 1: I've marked FRKWDTRDYAYPK 92, index is 4024, similarity 0.846, Mass difference 1.001
# 1: I've marked WNMFQDLHDYAYK 98, index is 4026, similarity 0.692, Mass difference 15.933
# 4: I've marked HLTWQWDREDYAK 99, index is 4036, similarity 0.692, Mass difference 31.983
# 2: I've marked WNLDKHDYSEKWK 94, index is 4043, similarity 0.692, Mass difference 0.057
# 2: I've marked WNDMHDYSHMLRK 90, index is 3976, similarity 0.769, Mass difference 16.037
# 1: I've marked WNLDKHDYSEKWK 94, index is 4043, similarity 0.692, Mass difference 0.057
# 2: I've marked WFVHDMEDYAMRK 89, index is 3944, similarity 0.692, Mass difference 21.968
# 4: I've marked FNWDEDREDYAYK 99, index is 4045, similarity 0.692, Mass difference 0.069
# 3: I've marked FNWDEDREDYAYK 99, index is 4045, similarity 0.692, Mass difference 0.069
# 2: I've marked YGWWLDHPDYSWK 96, index is 4055, similarity 0.692, Mass difference 1.037
# 2: I've marked RMDWHDYSYVHDK 91, index is 4097, similarity 0.923, Mass difference 15.999
# 1: I've marked YGWWLDYADYSWK 89, index is 4053, similarity 0.846, Mass difference 0.005
# 2: I've marked YGWWLDYADYSWK 89, index is 4053, similarity 0.846, Mass difference 0.005
# 2: I've marked YDALNWDVMYYRK 85, index is 3990, similarity 0.692, Mass difference 15.994
# 2: I've marked WMYPDWEDYSQKK 87, index is 4120, similarity 0.692, Mass difference 22.055
# 1: I've marked WDWPDYAHFRAYK 88, index is 4062, similarity 0.692, Mass difference 32.057
# 1: I've marked EYHSQDWQDYAWK 98, index is 4064, similarity 0.692, Mass difference 16.04
# 4: I've marked YTEHWDYEDYAHK 99, index is 4066, similarity 0.692, Mass difference 31.955
# 3: I've marked YEHDWEDYASYEK 99, index is 3980, similarity 0.692, Mass difference 22.027
# 2: I've marked HQEHWDYEDYAHK 87, index is 4070, similarity 0.846, Mass difference 1.005
# 4: I've marked FDRFDYADYRNMK 99, index is 4069, similarity 0.692, Mass difference 31.89
# 1: I've marked HQEHWDYEDYAHK 87, index is 4070, similarity 0.846, Mass difference 1.005
# 1: I've marked FRSMYDMPDYSWK 88, index is 4071, similarity 0.846, Mass difference 15.994
# 1: I've marked RWFNFDRKDYADK 92, index is 4077, similarity 0.692, Mass difference 32.025
# 1: I've marked NRDDMHDYSYFRK 86, index is 4083, similarity 0.692, Mass difference 21.941
# 1: I've marked NRDDMHDYSYFRK 86, index is 4083, similarity 0.692, Mass difference 1.024
# 5: I've marked TMWLWDQHDYAFK 99, index is 4002, similarity 0.692, Mass difference 21.977
# 4: I've marked WLWNNDWHDYADK 99, index is 4084, similarity 0.692, Mass difference 32.063
# 2: I've marked NRDDMHDYSYFRK 86, index is 4083, similarity 0.692, Mass difference 1.024
# 2: I've marked WNDWHDYSWKNTK 92, index is 4124, similarity 0.692, Mass difference 15.946
# 1: I've marked MYWHDRHDYARAK 91, index is 4090, similarity 0.692, Mass difference 21.979
# 1: I've marked RMDWHDYSYVHDK 91, index is 4097, similarity 0.923, Mass difference 15.999
# 1: I've marked RMDWHDYSYVHDK 91, index is 4097, similarity 0.692, Mass difference 32.044
# Step 2: 4100 of 4201
# 1: I've marked YWLFYDNRDYADK 98, index is 4102, similarity 0.692, Mass difference 0.991
# 2: I've marked YAEVYDWEDYAWK 97, index is 3992, similarity 0.692, Mass difference 32.042
# 2: I've marked YWLFYDNRDYADK 98, index is 4102, similarity 0.692, Mass difference 0.991
# 1: I've marked ENYDKHDYAFWRK 98, index is 4111, similarity 0.692, Mass difference 32.11
# 4: I've marked RYFWFDAQDYAYK 99, index is 4113, similarity 0.692, Mass difference 22.018
# 3: I've marked TMWLWDQHDYAFK 99, index is 4002, similarity 0.769, Mass difference 32.055
# 1: I've marked MFWNWDQRDYADK 96, index is 4117, similarity 0.692, Mass difference 0.021
# 2: I've marked MFWNWDQRDYADK 96, index is 4117, similarity 0.692, Mass difference 0.021
# 3: I've marked YFWWDTPDYAHFK 99, index is 4121, similarity 0.692, Mass difference 1.005
# 1: I've marked WMYPDWEDYSQKK 87, index is 4120, similarity 0.692, Mass difference 22.055
# 4: I've marked YFWWDTPDYAHFK 99, index is 4121, similarity 0.692, Mass difference 1.005
# 1: I've marked WNDWHDYSWKNTK 92, index is 4124, similarity 0.692, Mass difference 15.946
# 1: I've marked FYFFDDHHDYSYK 97, index is 4128, similarity 0.692, Mass difference 16.063
# 2: I've marked QWWPDRQDYAHRK 92, index is 4135, similarity 0.692, Mass difference 0.997
# 2: I've marked WFDLEDYAYHWNK 96, index is 4136, similarity 0.692, Mass difference 0.973
# 2: I've marked WMWFMPLPDYAWK 90, index is 4137, similarity 0.846, Mass difference 1.001
# 1: I've marked QWWPDRQDYAHRK 92, index is 4135, similarity 0.692, Mass difference 0.997
# 1: I've marked WFDLEDYAYHWNK 96, index is 4136, similarity 0.692, Mass difference 0.973
# 1: I've marked WMWFMPLPDYAWK 90, index is 4137, similarity 0.846, Mass difference 1.001
# 3: I've marked RYFWFDAQDYAYK 99, index is 4113, similarity 0.692, Mass difference 22.018
# 2: I've marked RMDWHDYSYVHDK 91, index is 4097, similarity 0.692, Mass difference 32.044
# 2: I've marked FYFFDDHHDYSYK 97, index is 4128, similarity 0.692, Mass difference 16.063
# 2: I've marked MDYHDYQARDWYK 87, index is 4160, similarity 0.692, Mass difference 0.895
# 1: I've marked MDYHDYQARDWYK 87, index is 4160, similarity 0.692, Mass difference 0.895
# 4: I've marked RLWFMDWHDYSHK 97, index is 4185, similarity 0.692, Mass difference 0.094
# 2: I've marked YFQFDWQDYARWK 88, index is 4191, similarity 0.769, Mass difference 15.996
# 3: I've marked RLWFMDWHDYSHK 97, index is 4185, similarity 0.692, Mass difference 0.094
# 1: I've marked YFQFDWQDYARWK 88, index is 4191, similarity 0.769, Mass difference 15.996
# 1: I've marked LYYYMTPWWPYWK 95, index is 4197, similarity 0.846, Mass difference 15.993
# 2: I've marked LYYYMTPWWPYWK 95, index is 4197, similarity 0.846, Mass difference 15.993
# Step 2: 4200 of 4201

# %%
# Remove peptides marked in Step 2 above, making a new dataframe
unique_to_drop = list(np.unique(to_drop))
new_index = list(df.index.values)
for bad_pep in unique_to_drop:
    new_index.remove(bad_pep)
df_intermed = df.iloc[new_index,:]
df_intermed.reset_index(drop=True,inplace=True)
print(f'Step 2 completed, removed {len(peptides)-len(df_intermed.index)} isomers')
# Out:
# Step 2 completed, removed 1568 isomers

# %%
# Step 3: Remove sequence isomers by high degree of similarity 
    # Similarity > 0.92, which is seen only for simple swap of 2 amino acids
# THIS IS AN EXTREMELY CONSERVATIVE STEP, sure to remove any POSSIBLE sequence isomers. On clean data, it removes <5% of the data
# RT cannot be used because different gradients were used to collect this data, but is reported

# Extract lists from dataframe for enumeration
peptides = df_intermed['Peptide'].tolist()
OPM = df_intermed['Obs Parent Mass'].tolist()
ALC = df_intermed['ALC (%)'].tolist()
ppm = df_intermed['ppm'].tolist()
RT = df_intermed['ppm'].tolist()

# Make a list of all the peptides to remove, Step 3:
similarity_cutoff = 0.92      # more than this

to_drop = []
for i in range(len(peptides)):
    if len(peptides) > 500 and i % 100 == 0: print(f"Step 3: {i} of {len(peptides)}")
    for k in range(len(peptides)):
        sim = difflib.SequenceMatcher(a=peptides[k], b=peptides[i])
        simz = sim.ratio()
        difference = np.abs(float(OPM[i]) - float(OPM[k]))
        RT_difference = np.abs(float(RT[i]) - float(RT[k]))
        if i != k and simz > similarity_cutoff:
            #print(f"Trouble {peptides[k]} {ALC[k]} {round(float(OPM[k]),3)} and {peptides[i]} {ALC[i]} {round(float(OPM[i]),3)}, similarity {round(float(simz),3)} difference {round(float(difference),3)}")
            if ALC[k] > ALC[i]:
                print(f"1: I've marked {peptides[i]} {ALC[i]}, index is {i}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}, RT difference {round(float(RT_difference),2)}")
                to_drop.append(i)
            elif ALC[k] < ALC[i]:
                print(f"2: I've marked {peptides[k]} {ALC[k]}, index is {k}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}, RT difference {round(float(RT_difference),2)}")
                to_drop.append(k)
            elif ALC[k] == ALC[i]:    
                if abs(float(ppm[k])) < abs(float(ppm[i])):
                    print(f"3: I've marked {peptides[k]} {ALC[k]}, index is {k}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}, RT difference {round(float(RT_difference),2)}")
                    to_drop.append(k)
                elif abs(float(ppm[i])) < abs(float(ppm[k])):
                    print(f"4: I've marked {peptides[i]} {ALC[i]}, index is {i}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}, RT difference {round(float(RT_difference),2)}")
                    to_drop.append(i)
                else:
                    print(f"5: I've marked {peptides[k]} {ALC[k]}, index is {k}, similarity {round(float(simz),3)}, Mass difference {round(float(difference),3)}, RT difference {round(float(RT_difference),2)}")
                    to_drop.append(k)
# Out:
# Step 3: 0 of 2633
# 4: I've marked GSASGLSFKGSHK 99, index is 2, similarity 0.923, Mass difference 26.048, RT difference 3.2
# 3: I've marked GSASGLSFKGSHK 99, index is 2, similarity 0.923, Mass difference 26.048, RT difference 3.2
# 2: I've marked ELASGLSFKGSHK 96, index is 20, similarity 0.923, Mass difference 72.021, RT difference 0.3
# 1: I've marked ELASGLSFKGSHK 96, index is 20, similarity 0.923, Mass difference 72.021, RT difference 0.3
# 2: I've marked VNPVMDVGDYAEK 98, index is 175, similarity 0.923, Mass difference 28.035, RT difference 2.6
# Step 3: 100 of 2633
# 1: I've marked VNPVMDVGDYAEK 98, index is 175, similarity 0.923, Mass difference 28.035, RT difference 2.6
# 4: I've marked EVDLSDYADKVGK 99, index is 185, similarity 0.923, Mass difference 34.019, RT difference 0.9
# Step 3: 200 of 2633
# Step 3: 300 of 2633
# 3: I've marked EVDLSDYADKVGK 99, index is 185, similarity 0.923, Mass difference 34.019, RT difference 0.9
# Step 3: 400 of 2633
# 4: I've marked LMGFQDVQDYAAK 99, index is 424, similarity 0.923, Mass difference 90.045, RT difference 0.8
# Step 3: 500 of 2633
# 4: I've marked KLLLHDVLDYAAK 99, index is 517, similarity 0.923, Mass difference 72.997, RT difference 0.9
# Step 3: 600 of 2633
# Step 3: 700 of 2633
# Step 3: 800 of 2633
# 3: I've marked LEDVEDYASSWLK 99, index is 979, similarity 0.923, Mass difference 12.042, RT difference 3.7
# Step 3: 900 of 2633
# 4: I've marked LEDVEDYASSWLK 99, index is 979, similarity 0.923, Mass difference 12.042, RT difference 3.7
# Step 3: 1000 of 2633
# Step 3: 1100 of 2633
# 3: I've marked KLLLHDVLDYAAK 99, index is 517, similarity 0.923, Mass difference 72.997, RT difference 0.9
# 2: I've marked KHLLDMEDYAQPK 97, index is 1489, similarity 0.923, Mass difference 30.037, RT difference 6.1
# 3: I've marked LMGFQDVQDYAAK 99, index is 424, similarity 0.923, Mass difference 90.045, RT difference 0.8
# Step 3: 1200 of 2633
# Step 3: 1300 of 2633
# Step 3: 1400 of 2633
# 1: I've marked KHLLDMEDYAQPK 97, index is 1489, similarity 0.923, Mass difference 30.037, RT difference 6.1
# Step 3: 1500 of 2633
# Step 3: 1600 of 2633
# 5: I've marked FYMQDKPDYAQVK 99, index is 1905, similarity 0.923, Mass difference 32.993, RT difference 0.0
# 2: I've marked MMSMVDPKDYSWK 95, index is 2059, similarity 0.923, Mass difference 47.985, RT difference 0.4
# Step 3: 1700 of 2633
# 2: I've marked MDVRDYADMMPRK 93, index is 2154, similarity 0.923, Mass difference 47.989, RT difference 2.4
# Step 3: 1800 of 2633
# Step 3: 1900 of 2633
# 5: I've marked FYNQDKPDYAQVK 99, index is 1614, similarity 0.923, Mass difference 32.993, RT difference 0.0
# Step 3: 2000 of 2633
# 1: I've marked MMSMVDPKDYSWK 95, index is 2059, similarity 0.923, Mass difference 47.985, RT difference 0.4
# Step 3: 2100 of 2633
# 1: I've marked MDVRDYADMMPRK 93, index is 2154, similarity 0.923, Mass difference 47.989, RT difference 2.4
# Step 3: 2200 of 2633
# Step 3: 2300 of 2633
# Step 3: 2400 of 2633
# Step 3: 2500 of 2633
# Step 3: 2600 of 2633

# %%
# Remove peptides marked in Step 3 above, making a new dataframe
unique_to_drop = list(np.unique(to_drop))
new_index = list(df_intermed.index.values)
for bad_pep in unique_to_drop:
    new_index.remove(bad_pep)
df_final = df_intermed.iloc[new_index,:]
df_final.reset_index(drop=True,inplace=True)
print(f'Step 3 completed, removed {len(peptides)-len(new_index)} potential isomers')
# Out:
# Step 3 completed, removed 12 potential isomers

# %%
# Save dataframe without index
df_final.to_csv(f'{file[:-4]}_clean.csv', index=False)
print(f"Output saved, of {len(ALC_list)} peptides originally present, {len(new_index)} were retained")
# Out:
# Output saved, of 4267 peptides originally present, 2621 were retained
